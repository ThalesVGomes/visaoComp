# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
from skimage import io

# %%
imgs = io.imread_collection("*.jpg")
io.imshow(imgs[0])
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: DejaVu Sans, Bitstream Vera Sans, Computer Modern Sans Serif, Lucida Grande, Verdana, Geneva, Lucid, Arial, Helvetica, Avant Garde, sans-serif
# --------------------------------------------------------------------
# ValueError                         Traceback (most recent call last)
# <ipython-input-7-8254388bd3f5> in <module>
#       1 imgs = io.imread_collection("*.jpg")
# ----> 2 io.imshow(imgs[0])
#
# ~/.local/lib/python3.9/site-packages/skimage/io/_io.py in imshow(arr, plugin, **plugin_args)
#     157     if isinstance(arr, str):
#     158         arr = call_plugin('imread', arr, plugin=plugin)
# --> 159     return call_plugin('imshow', arr, plugin=plugin, **plugin_args)
#     160
#     161
#
# ~/.local/lib/python3.9/site-packages/skimage/io/manage_plugins.py in call_plugin(kind, *args, **kwargs)
# ...

# %%
#copia da monitoria:

# mnist das imagens 

# - Vocês podem olhar nesses links outras formas de se fazer: (podem ir adicionando os links que vocês acharem aqui)
#  - https://gist.github.com/soply/f3eec2e79c165e39c9d540e916142ae1

n_colunas, n_linhas = 20, 10

fig, axs = plt.subplots(n_linhas, n_colunas, figsize=(20, 20))
num_fotos = n_colunas * n_linhas
for e, perfume in enumerate(imgs[:num_fotos]):
    l, c = (e // n_colunas, e % n_colunas)
    axs[l, c].imshow(perfume)
    axs[l, c].axis('off')
plt.show()

# %%
#copia da monitoria:

# Concatenar imagens usando o skimage
from skimage.io import concatenate_images
ic = concatenate_images(img[0:10])
ic.shape
